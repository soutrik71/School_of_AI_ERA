# %%
# Mount Google Drive
from google.colab import drive # import drive from google colab

ROOT = "/content/drive"     # default location for the drive
print(ROOT)                 # print content of ROOT (Optional)

drive.mount(ROOT,force_remount=True)           # we mount the google drive at /content/drive
# Out:
# /content/drive
# Mounted at /content/drive

# %%
# some basic setup commands

# %%
# %pwd
# Out:
# '/content'

# %%
# %ls
# Out:
# drive/  sample_data/

# %%
# %cd "drive/MyDrive"
# Out:
# /content/drive/MyDrive

# %%
# %pwd
# Out:
# '/content/drive/MyDrive'

# %%
# %ls
# Out:
# 'aadhaar card.pdf'
#  all_experience_letter_merge.pdf
# 'cancelled cheque.jpg'
# 'casual pic.jpeg'
#  Classroom/
# 'Colab Notebooks'/
#  Contacts123.vcf
#  contactssoutrik.vcf
#  Contacts.vcf
#  extras/
# 'Forecasting Models and Time Series for Business in Python'/
# 'Google Photos'/
# 'Id_card pic.jpeg'
#  iLovePDF/
#  images_ai/
# 'pan card.pdf'
#  passport.pdf
# 'praxis markshee-merged-compressed.pdf'
#  School_of_ai/
#  soutrik_A17032/
#  SoutrikChowdhury.pdf
#  YNAW/
#  Yoti/

# %%
# Clone github repository setup
# import join used to join ROOT path and MY_GOOGLE_DRIVE_PATH
from os.path import join

# path to your project on Google Drive
MY_GOOGLE_DRIVE_PATH = 'MyDrive/School_of_AI_ERA'
# replace with your Github username
GIT_USERNAME = "soutrik71"
# definitely replace with your
GIT_TOKEN = "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"
# Replace with your github repository in this case we want
# to clone deep-learning-v2-pytorch repository
GIT_REPOSITORY = "School_of_AI_ERA"

PROJECT_PATH = join(ROOT, f"MyDrive/{GIT_REPOSITORY}")

# # It's good to print out the value if you are not sure
print("PROJECT_PATH: ", PROJECT_PATH)

# # In case we haven't created the folder already; we will create a folder in the project path
# !mkdir "{PROJECT_PATH}"

#GIT_PATH = "https://{GIT_TOKEN}@github.com/{GIT_USERNAME}/{GIT_REPOSITORY}.git" this return 400 Bad Request for me
GIT_PATH = "https://" + GIT_TOKEN + "@github.com/" + GIT_USERNAME + "/" + GIT_REPOSITORY + ".git"
print("GIT_PATH: ", GIT_PATH)
# Out:
# PROJECT_PATH:  /content/drive/MyDrive/School_of_AI_ERA
# GIT_PATH:  https://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@github.com/soutrik71/School_of_AI_ERA.git

# %%
# %pwd
# Out:
# '/content/drive/MyDrive'

# %%
# !git clone "{GIT_PATH}"
# Out:
# Cloning into 'School_of_AI_ERA'...
# remote: Enumerating objects: 41, done.
# remote: Counting objects: 100% (41/41), done.
# remote: Compressing objects: 100% (36/36), done.
# remote: Total 41 (delta 11), reused 16 (delta 1), pack-reused 0
# Receiving objects: 100% (41/41), 18.31 MiB | 14.06 MiB/s, done.
# Resolving deltas: 100% (11/11), done.

# %%
# !git config --global user.email 'soutrik1991@gmail.com'
# !git config --global user.name 'soutrik71'

# %%
# %cd "{PROJECT_PATH}"
# Out:
# /content/drive/MyDrive/School_of_AI_ERA

# %%
# %ls
# Out:
# git_colab/  README.md  session1/  session2/  session3/  session4/  session5/

# %%
# !git branch
# Out:
# * main

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !mkdir git_colab

# %%
# !touch "git_colab/test.txt"

# %%
# !cp /content/drive/MyDrive/Colab Notebooks/GithubConnection.ipynb git_colab/test.txt
# Out:
# cp: cannot stat '/content/drive/MyDrive/Colab': No such file or directory
# cp: cannot stat 'Notebooks/GithubConnection.ipynb': No such file or directory

# %%
# !git
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	git_colab/
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git add . -v
# Out:
# add 'git_colab/test.txt'

# %%
# !git commit -m '"First commit with text file to etst connection with colab"'
# Out:
# [main 02f11c0] "First commit with text file to etst connection with colab"
#  1 file changed, 0 insertions(+), 0 deletions(-)
#  create mode 100644 git_colab/test.txt

# %%
# !git push origin main
# Out:
# Enumerating objects: 5, done.
# Counting objects: 100% (5/5), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (4/4), 340 bytes | 34.00 KiB/s, done.
# Total 4 (delta 1), reused 1 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/soutrik71/School_of_AI_ERA.git
#    7b1fcd1..02f11c0  main -> main
